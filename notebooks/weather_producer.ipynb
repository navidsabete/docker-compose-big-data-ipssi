# %%
# !pip install kafka-python requests
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.3.0-py2.py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests) (2023.7.22)
# Downloading kafka_python-2.3.0-py2.py3-none-any.whl (326 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.3/326.3 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.3.0

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("/home/jovyan/src")

from weather_producer import main, fetch_weather, transform_weather

main()
# Out:
# Weather streaming producer started...
# Sent to weather_transformed: {'time': '2026-01-30T17:45', 'interval': 900, 'temperature': 11.3, 'windspeed': 3.8, 'winddirection': 221, 'is_day': 0, 'weathercode': 3, 'temp_f': 52.34, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T17:45', 'interval': 900, 'temperature': 11.3, 'windspeed': 3.8, 'winddirection': 221, 'is_day': 0, 'weathercode': 3, 'temp_f': 52.34, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T17:45', 'interval': 900, 'temperature': 11.3, 'windspeed': 3.8, 'winddirection': 221, 'is_day': 0, 'weathercode': 3, 'temp_f': 52.34, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T17:45', 'interval': 900, 'temperature': 11.3, 'windspeed': 3.8, 'winddirection': 221, 'is_day': 0, 'weathercode': 3, 'temp_f': 52.34, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T17:45', 'interval': 900, 'temperature': 11.3, 'windspeed': 3.8, 'winddirection': 221, 'is_day': 0, 'weathercode': 3, 'temp_f': 52.34, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T17:45', 'interval': 900, 'temperature': 11.3, 'windspeed': 3.8, 'winddirection': 221, 'is_day': 0, 'weathercode': 3, 'temp_f': 52.34, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T17:45', 'interval': 900, 'temperature': 11.3, 'windspeed': 3.8, 'winddirection': 221, 'is_day': 0, 'weathercode': 3, 'temp_f': 52.34, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T17:45', 'interval': 900, 'temperature': 11.3, 'windspeed': 3.8, 'winddirection': 221, 'is_day': 0, 'weathercode': 3, 'temp_f': 52.34, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:00', 'interval': 900, 'temperature': 11.0, 'windspeed': 3.6, 'winddirection': 225, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.8, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:15', 'interval': 900, 'temperature': 10.8, 'windspeed': 3.1, 'winddirection': 234, 'is_day': 0, 'weathercode': 3, 'temp_f': 51.44, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 2.6, 'winddirection': 236, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.9, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T18:45', 'interval': 900, 'temperature': 10.4, 'windspeed': 2.3, 'winddirection': 252, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.72, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:00', 'interval': 900, 'temperature': 10.3, 'windspeed': 2.2, 'winddirection': 261, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.54, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 10.0, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 50.0, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 9.8, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.64, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 9.8, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.64, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 9.8, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.64, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 9.8, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.64, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 9.8, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.64, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 9.8, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.64, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 9.8, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.64, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:15', 'interval': 900, 'temperature': 9.8, 'windspeed': 2.2, 'winddirection': 279, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.64, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:30', 'interval': 900, 'temperature': 9.6, 'windspeed': 1.9, 'winddirection': 292, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.28, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# Sent to weather_transformed: {'time': '2026-01-30T19:45', 'interval': 900, 'temperature': 9.5, 'windspeed': 1.5, 'winddirection': 315, 'is_day': 0, 'weathercode': 3, 'temp_f': 49.1, 'high_wind_alert': False}
# ...
# Sent to weather_transformed: {'time': '2026-01-31T11:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 13.4, 'winddirection': 301, 'is_day': 1, 'weathercode': 61, 'temp_f': 50.9, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 13.4, 'winddirection': 301, 'is_day': 1, 'weathercode': 61, 'temp_f': 50.9, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 13.4, 'winddirection': 301, 'is_day': 1, 'weathercode': 61, 'temp_f': 50.9, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 13.4, 'winddirection': 301, 'is_day': 1, 'weathercode': 61, 'temp_f': 50.9, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 13.4, 'winddirection': 301, 'is_day': 1, 'weathercode': 61, 'temp_f': 50.9, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 13.4, 'winddirection': 301, 'is_day': 1, 'weathercode': 61, 'temp_f': 50.9, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 13.4, 'winddirection': 301, 'is_day': 1, 'weathercode': 61, 'temp_f': 50.9, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 13.4, 'winddirection': 301, 'is_day': 1, 'weathercode': 61, 'temp_f': 50.9, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:30', 'interval': 900, 'temperature': 10.5, 'windspeed': 13.4, 'winddirection': 301, 'is_day': 1, 'weathercode': 61, 'temp_f': 50.9, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T11:45', 'interval': 900, 'temperature': 10.9, 'windspeed': 13.8, 'winddirection': 303, 'is_day': 1, 'weathercode': 61, 'temp_f': 51.620000000000005, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:00', 'interval': 900, 'temperature': 11.2, 'windspeed': 14.2, 'winddirection': 306, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.16, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:15', 'interval': 900, 'temperature': 11.4, 'windspeed': 14.4, 'winddirection': 307, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.52, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:15', 'interval': 900, 'temperature': 11.4, 'windspeed': 14.4, 'winddirection': 307, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.52, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:15', 'interval': 900, 'temperature': 11.4, 'windspeed': 14.4, 'winddirection': 307, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.52, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:15', 'interval': 900, 'temperature': 11.4, 'windspeed': 14.4, 'winddirection': 307, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.52, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:15', 'interval': 900, 'temperature': 11.4, 'windspeed': 14.4, 'winddirection': 307, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.52, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:15', 'interval': 900, 'temperature': 11.4, 'windspeed': 14.4, 'winddirection': 307, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.52, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:15', 'interval': 900, 'temperature': 11.4, 'windspeed': 14.4, 'winddirection': 307, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.52, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:15', 'interval': 900, 'temperature': 11.4, 'windspeed': 14.4, 'winddirection': 307, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.52, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:15', 'interval': 900, 'temperature': 11.4, 'windspeed': 14.4, 'winddirection': 307, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.52, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:15', 'interval': 900, 'temperature': 11.4, 'windspeed': 14.4, 'winddirection': 307, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.52, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-31T12:15', 'interval': 900, 'temperature': 11.4, 'windspeed': 14.4, 'winddirection': 307, 'is_day': 1, 'weathercode': 3, 'temp_f': 52.52, 'high_wind_alert': True}
