# %%
# !pip install kafka-python requests

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("/home/jovyan/src")

from weather_producer import main, fetch_weather, transform_weather

main()
# Out:
# Weather streaming producer started...
# Sent to weather_transformed: {'time': '2026-01-22T10:15', 'interval': 900, 'temperature': 7.2, 'windspeed': 16.6, 'winddirection': 347, 'is_day': 1, 'weathercode': 61, 'temp_f': 44.96, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-22T10:15', 'interval': 900, 'temperature': 7.2, 'windspeed': 16.6, 'winddirection': 347, 'is_day': 1, 'weathercode': 61, 'temp_f': 44.96, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-22T10:15', 'interval': 900, 'temperature': 7.3, 'windspeed': 15.5, 'winddirection': 347, 'is_day': 1, 'weathercode': 61, 'temp_f': 45.14, 'high_wind_alert': True}
# Sent to weather_transformed: {'time': '2026-01-22T10:15', 'interval': 900, 'temperature': 7.3, 'windspeed': 15.5, 'winddirection': 347, 'is_day': 1, 'weathercode': 61, 'temp_f': 45.14, 'high_wind_alert': True}
# ...
